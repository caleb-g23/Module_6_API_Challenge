# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 589

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
base_url = f"https://api.openweathermap.org/data/2.5/weather?&appid={weather_api_key}&units=metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{base_url}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
       city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
       city_lat = city_weather["coord"]["lat"]
       city_lng = city_weather["coord"]["lon"]
       city_max_temp = city_weather["main"]["temp_max"]
       city_humidity = city_weather["main"]["humidity"]
       city_clouds = city_weather["clouds"]["all"]
       city_wind = city_weather["wind"]["speed"]
       city_country = city_weather["sys"]["country"]
       city_date = city_weather["dt"]

        # Append the City information into city_data list
       city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hotan
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | grytviken
# Processing Record 4 of Set 1 | takaungu
# Processing Record 5 of Set 1 | thompson
# Processing Record 6 of Set 1 | adamstown
# Processing Record 7 of Set 1 | port-aux-francais
# Processing Record 8 of Set 1 | edinburgh of the seven seas
# Processing Record 9 of Set 1 | alto barinas
# Processing Record 10 of Set 1 | ghadamis
# Processing Record 11 of Set 1 | formosa do rio preto
# Processing Record 12 of Set 1 | umluj
# Processing Record 13 of Set 1 | chonchi
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | hell-ville
# Processing Record 16 of Set 1 | puerto deseado
# Processing Record 17 of Set 1 | invercargill
# Processing Record 18 of Set 1 | olonkinbyen
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | aasiaat
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | timbuktu
# Processing Record 23 of Set 1 | fortuna
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | carnarvon
# Processing Record 26 of Set 1 | ilulissat
# Processing Record 27 of Set 1 | san antonio de pale
# Processing Record 28 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 29 of Set 1 | cisnadie
# Processing Record 30 of Set 1 | knyaze-volkonskoye
# Processing Record 31 of Set 1 | malvan
# Processing Record 32 of Set 1 | st. john's
# Processing Record 33 of Set 1 | muzayri'
# City not found. Skipping...
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | touros
# Processing Record 36 of Set 1 | ouarzazat
# Processing Record 37 of Set 1 | port mathurin
# Processing Record 38 of Set 1 | korhogo
# Processing Record 39 of Set 1 | tiksi
# Processing Record 40 of Set 1 | whangarei
# Processing Record 41 of Set 1 | hasaki
# Processing Record 42 of Set 1 | bilibino
# Processing Record 43 of Set 1 | uribia
# Processing Record 44 of Set 1 | monze
# Processing Record 45 of Set 1 | cedral
# Processing Record 46 of Set 1 | atherton
# Processing Record 47 of Set 1 | puerto natales
# Processing Record 48 of Set 1 | lhasa
# Processing Record 49 of Set 1 | udachny
# Processing Record 50 of Set 1 | whitehorse
# Processing Record 0 of Set 2 | blackmans bay
# Processing Record 1 of Set 2 | valsad
# Processing Record 2 of Set 2 | kavaratti
# Processing Record 3 of Set 2 | novyy urgal
# Processing Record 4 of Set 2 | sanctuary point
# Processing Record 5 of Set 2 | kingston
# Processing Record 6 of Set 2 | powell river
# Processing Record 7 of Set 2 | clarksville
# Processing Record 8 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | qaqortoq
# Processing Record 11 of Set 2 | atafu village
# Processing Record 12 of Set 2 | kirov
# Processing Record 13 of Set 2 | sarmiento
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | correntina
# Processing Record 16 of Set 2 | gizo
# Processing Record 17 of Set 2 | belmonte
# Processing Record 18 of Set 2 | carora
# Processing Record 19 of Set 2 | somerset east
# Processing Record 20 of Set 2 | arinos
# Processing Record 21 of Set 2 | moramanga
# Processing Record 22 of Set 2 | ushuaia
# Processing Record 23 of Set 2 | gadzhiyevo
# Processing Record 24 of Set 2 | margaret river
# Processing Record 25 of Set 2 | ust-nera
# Processing Record 26 of Set 2 | aswan
# Processing Record 27 of Set 2 | kailua-kona
# Processing Record 28 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 29 of Set 2 | hamilton
# Processing Record 30 of Set 2 | lebu
# Processing Record 31 of Set 2 | lompoc
# Processing Record 32 of Set 2 | sibenik
# Processing Record 33 of Set 2 | nova sintra
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | cururupu
# Processing Record 36 of Set 2 | aykhal
# Processing Record 37 of Set 2 | ribeira grande
# Processing Record 38 of Set 2 | remire-montjoly
# Processing Record 39 of Set 2 | iqaluit
# Processing Record 40 of Set 2 | ngaruawahia
# Processing Record 41 of Set 2 | kangding
# Processing Record 42 of Set 2 | pisco
# Processing Record 43 of Set 2 | akureyri
# Processing Record 44 of Set 2 | iskateley
# Processing Record 45 of Set 2 | hawaiian paradise park
# Processing Record 46 of Set 2 | tura
# Processing Record 47 of Set 2 | botou
# Processing Record 48 of Set 2 | puerto aysen
# Processing Record 49 of Set 2 | cat ba
# City not found. Skipping...
# Processing Record 0 of Set 3 | torghay
# Processing Record 1 of Set 3 | vorgashor
# Processing Record 2 of Set 3 | cargados carajos
# City not found. Skipping...
# Processing Record 3 of Set 3 | geri
# Processing Record 4 of Set 3 | quellon
# Processing Record 5 of Set 3 | greenville
# Processing Record 6 of Set 3 | dame-marie
# Processing Record 7 of Set 3 | dunedin
# Processing Record 8 of Set 3 | cabo san lucas
# Processing Record 9 of Set 3 | papatowai
# Processing Record 10 of Set 3 | wanning
# Processing Record 11 of Set 3 | mogadishu
# Processing Record 12 of Set 3 | north ward
# Processing Record 13 of Set 3 | tanrake village
# City not found. Skipping...
# Processing Record 14 of Set 3 | port lincoln
# Processing Record 15 of Set 3 | colonia
# Processing Record 16 of Set 3 | dompu
# Processing Record 17 of Set 3 | constantia
# Processing Record 18 of Set 3 | brahmapur
# Processing Record 19 of Set 3 | tsiombe
# Processing Record 20 of Set 3 | yuzhno-kurilsk
# Processing Record 21 of Set 3 | timbiras
# Processing Record 22 of Set 3 | nizhniy odes
# Processing Record 23 of Set 3 | kantharalak
# Processing Record 24 of Set 3 | wailua homesteads
# Processing Record 25 of Set 3 | utsunomiya
# Processing Record 26 of Set 3 | katsuren-haebaru
# Processing Record 27 of Set 3 | pyt-yakh
# Processing Record 28 of Set 3 | howard springs
# Processing Record 29 of Set 3 | trondheim
# Processing Record 30 of Set 3 | el porvenir
# Processing Record 31 of Set 3 | margate
# Processing Record 32 of Set 3 | taltal
# Processing Record 33 of Set 3 | waat
# Processing Record 34 of Set 3 | belyy yar
# Processing Record 35 of Set 3 | hobyo
# Processing Record 36 of Set 3 | quelimane
# Processing Record 37 of Set 3 | stanley
# Processing Record 38 of Set 3 | airdrie
# Processing Record 39 of Set 3 | geraldton
# Processing Record 40 of Set 3 | kishorganj
# Processing Record 41 of Set 3 | rusape
# Processing Record 42 of Set 3 | salinopolis
# Processing Record 43 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 44 of Set 3 | enewetak
# Processing Record 45 of Set 3 | mogocha
# Processing Record 46 of Set 3 | georgetown
# Processing Record 47 of Set 3 | poyarkovo
# Processing Record 48 of Set 3 | ovalle
# Processing Record 49 of Set 3 | ta`u
# Processing Record 0 of Set 4 | port alfred
# Processing Record 1 of Set 4 | washim
# Processing Record 2 of Set 4 | isangel
# Processing Record 3 of Set 4 | mount isa
# Processing Record 4 of Set 4 | greymouth
# Processing Record 5 of Set 4 | flying fish cove
# Processing Record 6 of Set 4 | talnakh
# Processing Record 7 of Set 4 | sassandra
# Processing Record 8 of Set 4 | petrolina
# Processing Record 9 of Set 4 | college
# Processing Record 10 of Set 4 | vila franca do campo
# Processing Record 11 of Set 4 | brokopondo
# Processing Record 12 of Set 4 | izluchinsk
# Processing Record 13 of Set 4 | ancud
# Processing Record 14 of Set 4 | sirte
# Processing Record 15 of Set 4 | mburucuya
# Processing Record 16 of Set 4 | west island
# Processing Record 17 of Set 4 | birjand
# Processing Record 18 of Set 4 | tazovsky
# Processing Record 19 of Set 4 | kamyanyets
# Processing Record 20 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 21 of Set 4 | nuuk
# Processing Record 22 of Set 4 | hadibu
# Processing Record 23 of Set 4 | fale old settlement
# Processing Record 24 of Set 4 | mahina
# Processing Record 25 of Set 4 | utrik
# Processing Record 26 of Set 4 | atakpame
# Processing Record 27 of Set 4 | ouadda
# Processing Record 28 of Set 4 | badger
# Processing Record 29 of Set 4 | santo antonio do ica
# Processing Record 30 of Set 4 | kamaishi
# Processing Record 31 of Set 4 | egilsstadir
# Processing Record 32 of Set 4 | east london
# Processing Record 33 of Set 4 | vilyuchinsk
# Processing Record 34 of Set 4 | sosnovka
# Processing Record 35 of Set 4 | isafjordur
# Processing Record 36 of Set 4 | san andres
# Processing Record 37 of Set 4 | new norfolk
# Processing Record 38 of Set 4 | san fernando
# Processing Record 39 of Set 4 | hermanus
# Processing Record 40 of Set 4 | minas de marcona
# Processing Record 41 of Set 4 | chillicothe
# Processing Record 42 of Set 4 | uturoa
# Processing Record 43 of Set 4 | harper
# Processing Record 44 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 45 of Set 4 | wenchang
# Processing Record 46 of Set 4 | santaluz
# Processing Record 47 of Set 4 | manuel ojinaga
# City not found. Skipping...
# Processing Record 48 of Set 4 | palmaner
# Processing Record 49 of Set 4 | maceio
# Processing Record 0 of Set 5 | andovoranto
# Processing Record 1 of Set 5 | kamikawa
# Processing Record 2 of Set 5 | masaya sur
# Processing Record 3 of Set 5 | fort st. john
# Processing Record 4 of Set 5 | vinogradovo
# Processing Record 5 of Set 5 | kodiak
# Processing Record 6 of Set 5 | kerikeri
# Processing Record 7 of Set 5 | mata-utu
# Processing Record 8 of Set 5 | sydney mines
# Processing Record 9 of Set 5 | nueva gerona
# Processing Record 10 of Set 5 | avarua
# Processing Record 11 of Set 5 | petal
# Processing Record 12 of Set 5 | meadow lakes
# Processing Record 13 of Set 5 | bel ombre
# Processing Record 14 of Set 5 | kupang
# Processing Record 15 of Set 5 | bardai
# Processing Record 16 of Set 5 | mana
# Processing Record 17 of Set 5 | novaya igirma
# Processing Record 18 of Set 5 | makhalino
# Processing Record 19 of Set 5 | santa rita
# Processing Record 20 of Set 5 | kitimat
# Processing Record 21 of Set 5 | burnet
# Processing Record 22 of Set 5 | ciudad bolivar
# Processing Record 23 of Set 5 | happy valley-goose bay
# Processing Record 24 of Set 5 | luderitz
# Processing Record 25 of Set 5 | igarka
# Processing Record 26 of Set 5 | klyuchi
# Processing Record 27 of Set 5 | port moresby
# Processing Record 28 of Set 5 | yelizovo
# Processing Record 29 of Set 5 | yemva
# Processing Record 30 of Set 5 | nueva villa de padilla
# Processing Record 31 of Set 5 | kiunga
# Processing Record 32 of Set 5 | pariaman
# Processing Record 33 of Set 5 | ola
# Processing Record 34 of Set 5 | novodvinsk
# Processing Record 35 of Set 5 | pitrufquen
# Processing Record 36 of Set 5 | faya-largeau
# Processing Record 37 of Set 5 | rio grande
# Processing Record 38 of Set 5 | praya
# Processing Record 39 of Set 5 | asia
# Processing Record 40 of Set 5 | vorkuta
# Processing Record 41 of Set 5 | solnechnyy
# Processing Record 42 of Set 5 | naze
# Processing Record 43 of Set 5 | fort bragg
# Processing Record 44 of Set 5 | berezovyy
# Processing Record 45 of Set 5 | gantang
# Processing Record 46 of Set 5 | tubarjal
# Processing Record 47 of Set 5 | villa unida
# City not found. Skipping...
# Processing Record 48 of Set 5 | ghat
# Processing Record 49 of Set 5 | bamboo flat
# Processing Record 0 of Set 6 | lycksele
# Processing Record 1 of Set 6 | rosetta
# Processing Record 2 of Set 6 | malango
# Processing Record 3 of Set 6 | kotel'va
# Processing Record 4 of Set 6 | mo i rana
# Processing Record 5 of Set 6 | afaahiti
# Processing Record 6 of Set 6 | arraial do cabo
# Processing Record 7 of Set 6 | odda
# Processing Record 8 of Set 6 | ratnagiri
# Processing Record 9 of Set 6 | alofi
# Processing Record 10 of Set 6 | gebeit
# Processing Record 11 of Set 6 | nemuro
# Processing Record 12 of Set 6 | xianju
# Processing Record 13 of Set 6 | morehead city
# Processing Record 14 of Set 6 | guajara
# Processing Record 15 of Set 6 | kramfors
# Processing Record 16 of Set 6 | howrah
# Processing Record 17 of Set 6 | jamestown
# Processing Record 18 of Set 6 | hammerfest
# Processing Record 19 of Set 6 | codajas
# Processing Record 20 of Set 6 | victorica
# Processing Record 21 of Set 6 | itoman
# Processing Record 22 of Set 6 | port saint john's
# Processing Record 23 of Set 6 | arkhangel'sk
# Processing Record 24 of Set 6 | mohacs
# Processing Record 25 of Set 6 | qujing
# Processing Record 26 of Set 6 | mili
# Processing Record 27 of Set 6 | kill devil hills
# Processing Record 28 of Set 6 | urengoy
# Processing Record 29 of Set 6 | lindi
# Processing Record 30 of Set 6 | covington
# Processing Record 31 of Set 6 | haiku-pauwela
# Processing Record 32 of Set 6 | stephenville
# Processing Record 33 of Set 6 | cobh
# Processing Record 34 of Set 6 | sabang
# Processing Record 35 of Set 6 | el granada
# Processing Record 36 of Set 6 | dudinka
# Processing Record 37 of Set 6 | olinda
# Processing Record 38 of Set 6 | guiuan
# Processing Record 39 of Set 6 | san luis de la loma
# Processing Record 40 of Set 6 | al bayda'
# Processing Record 41 of Set 6 | g'uzor
# Processing Record 42 of Set 6 | port augusta
# Processing Record 43 of Set 6 | sechura
# Processing Record 44 of Set 6 | artigas
# Processing Record 45 of Set 6 | holualoa
# Processing Record 46 of Set 6 | barra de santo antonio
# Processing Record 47 of Set 6 | kenai
# Processing Record 48 of Set 6 | ulsteinvik
# Processing Record 49 of Set 6 | betio village
# Processing Record 0 of Set 7 | usinsk
# Processing Record 1 of Set 7 | inari
# Processing Record 2 of Set 7 | lydenburg
# Processing Record 3 of Set 7 | freetown
# Processing Record 4 of Set 7 | paraiso
# Processing Record 5 of Set 7 | yanam
# Processing Record 6 of Set 7 | beira
# Processing Record 7 of Set 7 | paita
# Processing Record 8 of Set 7 | jefferson city
# Processing Record 9 of Set 7 | bereeda
# Processing Record 10 of Set 7 | mossel bay
# Processing Record 11 of Set 7 | mekhe
# Processing Record 12 of Set 7 | saipan
# Processing Record 13 of Set 7 | kilindoni
# Processing Record 14 of Set 7 | rundu
# Processing Record 15 of Set 7 | lihue
# Processing Record 16 of Set 7 | phan rang-thap cham
# Processing Record 17 of Set 7 | vershino-darasunskiy
# Processing Record 18 of Set 7 | kapuskasing
# Processing Record 19 of Set 7 | kapa'a
# Processing Record 20 of Set 7 | markovo
# Processing Record 21 of Set 7 | palasa
# Processing Record 22 of Set 7 | tazacorte
# Processing Record 23 of Set 7 | sharlyk
# Processing Record 24 of Set 7 | cidreira
# Processing Record 25 of Set 7 | tan-tan
# Processing Record 26 of Set 7 | vallenar
# Processing Record 27 of Set 7 | nouadhibou
# Processing Record 28 of Set 7 | kyain seikgyi township
# City not found. Skipping...
# Processing Record 29 of Set 7 | polyarnyy
# Processing Record 30 of Set 7 | port elizabeth
# Processing Record 31 of Set 7 | bargara
# City not found. Skipping...
# Processing Record 32 of Set 7 | redencao
# Processing Record 33 of Set 7 | simpang
# Processing Record 34 of Set 7 | novyy urengoy
# Processing Record 35 of Set 7 | envira
# Processing Record 36 of Set 7 | guerrero negro
# Processing Record 37 of Set 7 | island harbour
# Processing Record 38 of Set 7 | brisas de zicatela
# Processing Record 39 of Set 7 | san julian
# Processing Record 40 of Set 7 | cobram
# Processing Record 41 of Set 7 | catia la mar
# Processing Record 42 of Set 7 | susuman
# Processing Record 43 of Set 7 | hilo
# Processing Record 44 of Set 7 | porto novo
# Processing Record 45 of Set 7 | coquimbo
# Processing Record 46 of Set 7 | nantucket
# Processing Record 47 of Set 7 | borba
# Processing Record 48 of Set 7 | ironwood
# Processing Record 49 of Set 7 | grand falls-windsor
# Processing Record 0 of Set 8 | zarand
# Processing Record 1 of Set 8 | pishva
# Processing Record 2 of Set 8 | noumea
# Processing Record 3 of Set 8 | metkovic
# Processing Record 4 of Set 8 | alice springs
# Processing Record 5 of Set 8 | mezhdurechenskiy
# Processing Record 6 of Set 8 | codrington
# Processing Record 7 of Set 8 | san pedro
# Processing Record 8 of Set 8 | dunyapur
# Processing Record 9 of Set 8 | tolanaro
# Processing Record 10 of Set 8 | bodaybo
# Processing Record 11 of Set 8 | mitu
# Processing Record 12 of Set 8 | anadyr
# Processing Record 13 of Set 8 | impfondo
# Processing Record 14 of Set 8 | walvis bay
# Processing Record 15 of Set 8 | chiriguana
# Processing Record 16 of Set 8 | plastun
# Processing Record 17 of Set 8 | illizi
# Processing Record 18 of Set 8 | bangassou
# Processing Record 19 of Set 8 | mount pearl
# Processing Record 20 of Set 8 | laojunmiao
# Processing Record 21 of Set 8 | nar'yan-mar
# Processing Record 22 of Set 8 | inongo
# Processing Record 23 of Set 8 | lazarevskoye
# Processing Record 24 of Set 8 | eduardo castex
# Processing Record 25 of Set 8 | kayangel
# Processing Record 26 of Set 8 | chibougamau
# Processing Record 27 of Set 8 | kilju
# Processing Record 28 of Set 8 | pierre
# Processing Record 29 of Set 8 | palikir - national government center
# Processing Record 30 of Set 8 | durban
# Processing Record 31 of Set 8 | vila velha
# Processing Record 32 of Set 8 | keflavik
# Processing Record 33 of Set 8 | bayganin
# Processing Record 34 of Set 8 | coahuayana de hidalgo
# Processing Record 35 of Set 8 | whitby
# Processing Record 36 of Set 8 | yazoo city
# Processing Record 37 of Set 8 | mocimboa
# Processing Record 38 of Set 8 | thurso
# Processing Record 39 of Set 8 | orlov
# Processing Record 40 of Set 8 | minggang
# Processing Record 41 of Set 8 | vanino
# Processing Record 42 of Set 8 | kataragama
# City not found. Skipping...
# Processing Record 43 of Set 8 | pangody
# Processing Record 44 of Set 8 | banlung
# Processing Record 45 of Set 8 | prainha
# Processing Record 46 of Set 8 | tutoia
# Processing Record 47 of Set 8 | mzimba
# Processing Record 48 of Set 8 | sola
# Processing Record 49 of Set 8 | orapa
# Processing Record 0 of Set 9 | abu zabad
# Processing Record 1 of Set 9 | loralai
# Processing Record 2 of Set 9 | kanke
# Processing Record 3 of Set 9 | matoury
# Processing Record 4 of Set 9 | mount gambier
# Processing Record 5 of Set 9 | micheweni
# Processing Record 6 of Set 9 | bengkulu
# Processing Record 7 of Set 9 | luanda
# Processing Record 8 of Set 9 | oodweyne
# Processing Record 9 of Set 9 | kutum
# Processing Record 10 of Set 9 | idaho falls
# Processing Record 11 of Set 9 | zhoukou
# Processing Record 12 of Set 9 | usogorsk
# Processing Record 13 of Set 9 | angaur state
# Processing Record 14 of Set 9 | port-gentil
# Processing Record 15 of Set 9 | san andros
# City not found. Skipping...
# Processing Record 16 of Set 9 | cannonvale
# Processing Record 17 of Set 9 | kununurra
# Processing Record 18 of Set 9 | cochirleanca
# Processing Record 19 of Set 9 | varzea da palma
# Processing Record 20 of Set 9 | lerwick
# Processing Record 21 of Set 9 | prince rupert
# Processing Record 22 of Set 9 | papao
# Processing Record 23 of Set 9 | taoudenni
# Processing Record 24 of Set 9 | raja
# Processing Record 25 of Set 9 | kihangara
# Processing Record 26 of Set 9 | brookings
# Processing Record 27 of Set 9 | latakia
# Processing Record 28 of Set 9 | amalapuram
# Processing Record 29 of Set 9 | dolinsk
# Processing Record 30 of Set 9 | caleta de carquin
# Processing Record 31 of Set 9 | tyukhtet
# Processing Record 32 of Set 9 | gaoual
# Processing Record 33 of Set 9 | celestun
# Processing Record 34 of Set 9 | burao
# Processing Record 35 of Set 9 | dryden
# Processing Record 36 of Set 9 | sonsorol village
# City not found. Skipping...
# Processing Record 37 of Set 9 | mpika
# Processing Record 38 of Set 9 | upington
# Processing Record 39 of Set 9 | brak
# Processing Record 40 of Set 9 | russkaya polyana
# Processing Record 41 of Set 9 | okha
# Processing Record 42 of Set 9 | buarcos
# Processing Record 43 of Set 9 | thames
# Processing Record 44 of Set 9 | ntungamo
# Processing Record 45 of Set 9 | blagoveshchenka
# Processing Record 46 of Set 9 | bikin
# Processing Record 47 of Set 9 | arica
# Processing Record 48 of Set 9 | salalah
# Processing Record 49 of Set 9 | mayqayyng
# Processing Record 0 of Set 10 | san jose village
# City not found. Skipping...
# Processing Record 1 of Set 10 | jeremie
# Processing Record 2 of Set 10 | falavarjan
# Processing Record 3 of Set 10 | tofol
# Processing Record 4 of Set 10 | santyoku
# Processing Record 5 of Set 10 | golyshmanovo
# Processing Record 6 of Set 10 | leiyang
# Processing Record 7 of Set 10 | kulunda
# Processing Record 8 of Set 10 | zapolyarnyy
# Processing Record 9 of Set 10 | sandnessjoen
# Processing Record 10 of Set 10 | carutapera
# Processing Record 11 of Set 10 | pudasjarvi
# Processing Record 12 of Set 10 | kovalam
# Processing Record 13 of Set 10 | feodosiya
# Processing Record 14 of Set 10 | lyantor
# Processing Record 15 of Set 10 | lisakovsk
# Processing Record 16 of Set 10 | port macquarie
# Processing Record 17 of Set 10 | pitimbu
# Processing Record 18 of Set 10 | moranbah
# Processing Record 19 of Set 10 | chulakkurgan
# Processing Record 20 of Set 10 | zhumysker
# Processing Record 21 of Set 10 | yangshuo
# Processing Record 22 of Set 10 | sao joao da barra
# Processing Record 23 of Set 10 | cabedelo
# Processing Record 24 of Set 10 | anahuac
# Processing Record 25 of Set 10 | portland
# Processing Record 26 of Set 10 | boyolangu
# Processing Record 27 of Set 10 | baruun-urt
# Processing Record 28 of Set 10 | inhambane
# Processing Record 29 of Set 10 | as sulayyil
# Processing Record 30 of Set 10 | sekong
# Processing Record 31 of Set 10 | napier
# Processing Record 32 of Set 10 | lazaro cardenas
# Processing Record 33 of Set 10 | bundu
# Processing Record 34 of Set 10 | barcelos
# Processing Record 35 of Set 10 | saudarkrokur
# Processing Record 36 of Set 10 | mineiros
# Processing Record 37 of Set 10 | kidal
# Processing Record 38 of Set 10 | guaranda
# Processing Record 39 of Set 10 | nadi
# Processing Record 40 of Set 10 | pergamino
# Processing Record 41 of Set 10 | zaragoza
# Processing Record 42 of Set 10 | fort mcmurray
# Processing Record 43 of Set 10 | rikaze
# Processing Record 44 of Set 10 | xique xique
# Processing Record 45 of Set 10 | vernon
# Processing Record 46 of Set 10 | rey bouba
# Processing Record 47 of Set 10 | frontera
# Processing Record 48 of Set 10 | maragogi
# Processing Record 49 of Set 10 | kone
# Processing Record 0 of Set 11 | chernyshevskiy
# Processing Record 1 of Set 11 | hoemul-li
# Processing Record 2 of Set 11 | la passe
# Processing Record 3 of Set 11 | kanniyakumari
# Processing Record 4 of Set 11 | ballycastle
# Processing Record 5 of Set 11 | saint-philippe
# Processing Record 6 of Set 11 | chakia
# Processing Record 7 of Set 11 | al ain city
# Processing Record 8 of Set 11 | tonj
# Processing Record 9 of Set 11 | road town
# Processing Record 10 of Set 11 | cadale
# Processing Record 11 of Set 11 | qarazhal
# Processing Record 12 of Set 11 | talara
# Processing Record 13 of Set 11 | crane
# Processing Record 14 of Set 11 | sisimiut
# Processing Record 15 of Set 11 | daru
# Processing Record 16 of Set 11 | turpan
# Processing Record 17 of Set 11 | pontes e lacerda
# Processing Record 18 of Set 11 | alesund
# Processing Record 19 of Set 11 | harnai
# Processing Record 20 of Set 11 | ordos
# City not found. Skipping...
# Processing Record 21 of Set 11 | rongelap
# Processing Record 22 of Set 11 | saldanha
# Processing Record 23 of Set 11 | rice lake
# Processing Record 24 of Set 11 | kimberley
# Processing Record 25 of Set 11 | aparri
# Processing Record 26 of Set 11 | xingcheng
# Processing Record 27 of Set 11 | yukhnov
# Processing Record 28 of Set 11 | san patricio
# Processing Record 29 of Set 11 | plettenberg bay
# Processing Record 30 of Set 11 | saynshand
# Processing Record 31 of Set 11 | kayenta
# Processing Record 32 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 33 of Set 11 | saint-paul
# Processing Record 34 of Set 11 | cheremushki
# Processing Record 35 of Set 11 | santa elena de uairen
# Processing Record 36 of Set 11 | port-vila
# Processing Record 37 of Set 11 | chichiriviche
# Processing Record 38 of Set 11 | sebdou
# Processing Record 39 of Set 11 | weno
# Processing Record 40 of Set 11 | teluknaga
# Processing Record 41 of Set 11 | matsubase
# Processing Record 42 of Set 11 | castillos
# Processing Record 43 of Set 11 | camiri
# Processing Record 44 of Set 11 | shingu
# Processing Record 45 of Set 11 | carolina beach
# Processing Record 46 of Set 11 | namibe
# Processing Record 47 of Set 11 | lospalos
# Processing Record 48 of Set 11 | batangafo
# Processing Record 49 of Set 11 | broome
# Processing Record 0 of Set 12 | tabou
# Processing Record 1 of Set 12 | horta
# Processing Record 2 of Set 12 | nadym
# Processing Record 3 of Set 12 | yerofey pavlovich
# Processing Record 4 of Set 12 | puerto baquerizo moreno
# Processing Record 5 of Set 12 | chota
# Processing Record 6 of Set 12 | cromwell
# Processing Record 7 of Set 12 | pavlovka
# Processing Record 8 of Set 12 | sao gabriel da cachoeira
# Processing Record 9 of Set 12 | bikenibeu village
# Processing Record 10 of Set 12 | quesada
# Processing Record 11 of Set 12 | huitel
# Processing Record 12 of Set 12 | el calafate
# Processing Record 13 of Set 12 | ebon
# Processing Record 14 of Set 12 | mumbwa
# Processing Record 15 of Set 12 | ocean pointe
# City not found. Skipping...
# Processing Record 16 of Set 12 | astara
# Processing Record 17 of Set 12 | general villegas
# Processing Record 18 of Set 12 | merizo village
# Processing Record 19 of Set 12 | charters towers
# Processing Record 20 of Set 12 | antofagasta
# Processing Record 21 of Set 12 | goz beida
# Processing Record 22 of Set 12 | shaping
# Processing Record 23 of Set 12 | sitka
# Processing Record 24 of Set 12 | qingquan
# Processing Record 25 of Set 12 | posto fiscal rolim de moura
# Processing Record 26 of Set 12 | drayton valley
# Processing Record 27 of Set 12 | gurupi
# Processing Record 28 of Set 12 | les avirons
# Processing Record 29 of Set 12 | sarkand
# Processing Record 30 of Set 12 | corinto
# Processing Record 31 of Set 12 | karratha
# Processing Record 32 of Set 12 | monroe
# Processing Record 33 of Set 12 | jianguang
# Processing Record 34 of Set 12 | newport
# Processing Record 35 of Set 12 | natal
# Processing Record 36 of Set 12 | marang
# Processing Record 37 of Set 12 | naberera
# Processing Record 38 of Set 12 | plouzane
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          569
# Lat           569
# Lng           569
# Max Temp      569
# Humidity      569
# Cloudiness    569
# Wind Speed    569
# Country       569
# Date          569
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#         City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      hotan  37.0997   79.9269     15.33        35          81        4.18
# 1   waitangi -43.9535 -176.5597     13.23        95         100        2.68
# 2  grytviken -54.2811  -36.5092     -1.02        79          98        4.94
# 3   takaungu  -3.6837   39.8566     25.16        85          13        6.02
# 4   thompson  55.7435  -97.8558     19.67        41          74        1.93
#
#   Country        Date
# 0      CN  1695489341
# 1      NZ  1695488953
# 2      GS  1695488947
# 3      KE  1695489341
# 4      CA  1695488962

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            hotan  37.0997   79.9269     15.33        35          81
# 1         waitangi -43.9535 -176.5597     13.23        95         100
# 2        grytviken -54.2811  -36.5092     -1.02        79          98
# 3         takaungu  -3.6837   39.8566     25.16        85          13
# 4         thompson  55.7435  -97.8558     19.67        41          74
#
#          Wind Speed Country        Date
# City_ID
# 0              4.18      CN  1695489341
# 1              2.68      NZ  1695488953
# 2              4.94      GS  1695488947
# 3              6.02      KE  1695489341
# 4              1.93      CA  1695488962

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker = 'o')

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#####LAT VS MAX TEMP#######
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,260),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.3334852385766454

# %%
# Define a function to create Linear Regression plots
#####LAT VS Humidity#######
x_values = city_data_df['Lat']
y_values = city_data_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.05128832550878805

# %%
# Define a function to create Linear Regression plots
#####LAT VS Cloudiness#######
x_values = city_data_df['Lat']
y_values = city_data_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-40,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.08268951635011854

# %%
# Define a function to create Linear Regression plots
#####LAT VS Wind Speed#######
x_values = city_data_df['Lat']
y_values = city_data_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,-0),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.13141296725473506

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               hotan  37.0997  79.9269     15.33        35          81
# 4            thompson  55.7435 -97.8558     19.67        41          74
# 8        alto barinas   8.5931 -70.2261     33.44        46          25
# 9            ghadamis  30.1337   9.5007     37.20        11          83
# 11              umluj  25.0213  37.2685     30.20        67           1
#
#          Wind Speed Country        Date
# City_ID
# 0              4.18      CN  1695489341
# 4              1.93      CA  1695488962
# 8              2.77      VE  1695489343
# 9              3.64      LY  1695489343
# 11             3.15      SA  1695489344

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                 waitangi -43.9535 -176.5597     13.23        95         100
# 2                grytviken -54.2811  -36.5092     -1.02        79          98
# 3                 takaungu  -3.6837   39.8566     25.16        85          13
# 5                adamstown -25.0660 -130.1015     20.44        89          90
# 6        port-aux-francais -49.3500   70.2167      1.96        87          90
#
#          Wind Speed Country        Date
# City_ID
# 1              2.68      NZ  1695488953
# 2              4.94      GS  1695488947
# 3              6.02      KE  1695489341
# 5             11.77      PN  1695488956
# 6             22.28      TF  1695488943

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,270),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Max Temperature')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.8296554893588286

# %% [markdown]
# **Discussion about the linear relationship:**
# The r-value of -0.86 suggests that there is a strong correlation between latitude and max temp in the northern hemisphere

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,295),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Max Temperature')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.7658155355457549

# %% [markdown]
# **Discussion about the linear relationship:**
# The r-value of 0.334 suggests that there is a weak to moderate correlation between latitude and max temp in the southern hemisphere

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,45),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Humidity')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.1130223496342879

# %% [markdown]
# **Discussion about the linear relationship:**
# the r-value of 0.419 suggests that there is a moderate positive correlation between latitude and humidity in the northern hemisphere

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Humidity')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.1657423275872484

# %% [markdown]
# **Discussion about the linear relationship:**
# the r-value of 0.310 suggests that there is a weak positive correlation between latitude and humidity in the southern hemisphere

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,45),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.07180855713129873

# %% [markdown]
# **Discussion about the linear relationship:**
# the r-value of 0.218 suggests that there is not a strong positive correlation between latitude and cloudiness in the northern hemisphere

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.2333130089893064

# %% [markdown]
# **Discussion about the linear relationship:**
# the r-value of 0.422 suggests that there is moderate positive correlation between latitude and cloudiness in the southern hemisphere

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,8),fontsize=15,color="red")
plt.xlabel('Northern Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:0.030138384059404708

# %% [markdown]
# **Discussion about the linear relationship:**
# the r-value of 0.011 suggests that there is almost no correlation between latitude and wind speed in the northern hemisphere

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,55),fontsize=15,color="red")
plt.xlabel('Southern Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is:{rvalue}")
plt.show()
# Out:
# The r-value is:-0.0584879006655313

# %% [markdown]
# **Discussion about the linear relationship:**
# the r-value of -0.190 suggests that there is a weak negative correlation between latitude and wind speed in the southern hemisphere
